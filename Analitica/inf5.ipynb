# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('./data.xlsx',header=None).T

muestra = data.iloc[:,0].ffill()
data.index = [muestra , data.iloc[:,2]]
data = (data.iloc[:,4:]
        .dropna())

data
# Out:
#                                                                                 4    \
# 0                       2
# Blanco                  Potencial(V)                                       -0.20004
#                         Corriente (microA)                                  1.26657
# Muestra 1               Potencial(V)                                       -0.20004
#                         Corriente (microA)                                        0
#                         Corriente corregida (microA)                       -1.26657
# Muestra 2               Potencial(V)                                       -0.20004
#                         Corriente (microA)                                        0
#                         Corriente corregida (microA)                       -1.26657
# Muestra 2 Dilución 4/25 Potencial(V)                                       -0.20004
#                         Corriente (microA)                                        0
# ...

# %%
blanco = data.loc['Blanco']
Ib = blanco.iloc[1] #Corriente blanco

for m in muestra.unique():
    DataMue = data.loc[m]
    plt.plot(DataMue.iloc[0],
             DataMue.iloc[1]-Ib,
             label=m,
             color='r')
    plt.legend()
    plt.show()
